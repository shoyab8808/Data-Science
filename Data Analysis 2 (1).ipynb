# %%
import pandas as pd

# %%
df = pd.read_csv("Flipkart_laptops.csv")

# %%
df
# Out:
#      Unnamed: 0                                               Name  Price  \
# 0             0  acer Aspire 7 Core i5 12th Gen - (8 GB/512 GB ...  57490
# 1             1  acer Aspire 7 Core i5 12th Gen - (16 GB/512 GB...  53990
# 2             2  DELL Inspiron Ryzen 3 Dual Core 3250U - (8 GB/...  39690
# 3             3  Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  44999
# 4             4  ASUS Vivobook 15 Core i3 10th Gen - (8 GB/256 ...  27990
# ..          ...                                                ...    ...
# 931         931  acer Nitro 5 Ryzen 5 Hexa Core AMD R5-5600H - ...  57990
# 932         932  HP 14s Core i3 11th Gen - (8 GB/256 GB SSD/Win...  40400
# 933         933  DELL Athlon Dual Core 11th Gen - (8 GB/256 GB ...  34499
# 934         934  DELL Core i5 11th Gen - (8 GB/512 GB SSD/Windo...  56990
# 935         935  Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...  53990
#
#      Rating
# 0       4.3
# 1       4.3
# 2       4.3
# 3       4.3
# ...

# %% [markdown]
# index_col: This is to allow you to set which columns to be used as the index of the dataframe. The default value is None, and pandas will add a new column start from 0 to specify the index column. It can be set as a column name or column index, which will be used as the index column.

# %%
df = pd.read_csv('Flipkart_laptops.csv', index_col = 0)

# %%
df
# Out:
#                                                   Name  Price  Rating
# 0    acer Aspire 7 Core i5 12th Gen - (8 GB/512 GB ...  57490     4.3
# 1    acer Aspire 7 Core i5 12th Gen - (16 GB/512 GB...  53990     4.3
# 2    DELL Inspiron Ryzen 3 Dual Core 3250U - (8 GB/...  39690     4.3
# 3    Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  44999     4.3
# 4    ASUS Vivobook 15 Core i3 10th Gen - (8 GB/256 ...  27990     4.3
# ..                                                 ...    ...     ...
# 931  acer Nitro 5 Ryzen 5 Hexa Core AMD R5-5600H - ...  57990     4.3
# 932  HP 14s Core i3 11th Gen - (8 GB/256 GB SSD/Win...  40400     4.3
# 933  DELL Athlon Dual Core 11th Gen - (8 GB/256 GB ...  34499     4.3
# 934  DELL Core i5 11th Gen - (8 GB/512 GB SSD/Windo...  56990     4.3
# 935  Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...  53990     4.3
#
# [936 rows x 3 columns]

# %% [markdown]
# # Usecols

# %% [markdown]
# You can use the usecols argument within the read_csv() function to read specific columns from a CSV file into a pandas DataFrame.

# %% [markdown]
# # Method 1: Use usecols with Column Names

# %% [markdown]
# df = pd.read_csv('my_data.csv', usecols=['this_column', 'that_column'])

# %% [markdown]
# # Method 2: Use usecols with Column Positions

# %% [markdown]
# df = pd.read_csv('my_data.csv', usecols=[0, 2])

# %%
df = pd.read_csv('Flipkart_laptops.csv', usecols=["Name", "Price", "Rating"])
df
# Out:
#                                                   Name  Price  Rating
# 0    acer Aspire 7 Core i5 12th Gen - (8 GB/512 GB ...  57490     4.3
# 1    acer Aspire 7 Core i5 12th Gen - (16 GB/512 GB...  53990     4.3
# 2    DELL Inspiron Ryzen 3 Dual Core 3250U - (8 GB/...  39690     4.3
# 3    Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  44999     4.3
# 4    ASUS Vivobook 15 Core i3 10th Gen - (8 GB/256 ...  27990     4.3
# ..                                                 ...    ...     ...
# 931  acer Nitro 5 Ryzen 5 Hexa Core AMD R5-5600H - ...  57990     4.3
# 932  HP 14s Core i3 11th Gen - (8 GB/256 GB SSD/Win...  40400     4.3
# 933  DELL Athlon Dual Core 11th Gen - (8 GB/256 GB ...  34499     4.3
# 934  DELL Core i5 11th Gen - (8 GB/512 GB SSD/Windo...  56990     4.3
# 935  Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...  53990     4.3
#
# [936 rows x 3 columns]

# %%
df = pd.read_csv('Flipkart_laptops.csv', usecols=["Name", "Price", "Rating"], nrows = 100)
df
# Out:
#                                                  Name  Price  Rating
# 0   acer Aspire 7 Core i5 12th Gen - (8 GB/512 GB ...  57490     4.3
# 1   acer Aspire 7 Core i5 12th Gen - (16 GB/512 GB...  53990     4.3
# 2   DELL Inspiron Ryzen 3 Dual Core 3250U - (8 GB/...  39690     4.3
# 3   Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  44999     4.3
# 4   ASUS Vivobook 15 Core i3 10th Gen - (8 GB/256 ...  27990     4.3
# ..                                                ...    ...     ...
# 95  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...  37990     4.3
# 96  Infinix INBook X1 Neo Series Celeron Quad Core...  18990     4.6
# 97  HP Pavilion x360 Core i3 11th Gen - (8 GB/256 ...  46990     4.6
# 98  ASUS VivoBook Core i3 11th Gen - (8 GB/256 GB ...  32990     4.6
# 99  acer Aspire 7 Core i5 12th Gen - (8 GB/512 GB ...  57490     4.6
#
# [100 rows x 3 columns]

# %%
df = pd.read_csv('Flipkart_laptops.csv', index_col = 0)
df
# Out:
#                                                   Name  Price  Rating
# 0    acer Aspire 7 Core i5 12th Gen - (8 GB/512 GB ...  57490     4.3
# 1    acer Aspire 7 Core i5 12th Gen - (16 GB/512 GB...  53990     4.3
# 2    DELL Inspiron Ryzen 3 Dual Core 3250U - (8 GB/...  39690     4.3
# 3    Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  44999     4.3
# 4    ASUS Vivobook 15 Core i3 10th Gen - (8 GB/256 ...  27990     4.3
# ..                                                 ...    ...     ...
# 931  acer Nitro 5 Ryzen 5 Hexa Core AMD R5-5600H - ...  57990     4.3
# 932  HP 14s Core i3 11th Gen - (8 GB/256 GB SSD/Win...  40400     4.3
# 933  DELL Athlon Dual Core 11th Gen - (8 GB/256 GB ...  34499     4.3
# 934  DELL Core i5 11th Gen - (8 GB/512 GB SSD/Windo...  56990     4.3
# 935  Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...  53990     4.3
#
# [936 rows x 3 columns]

# %% [markdown]
# The head() method returns a specified number of rows, string from the top

# %%
df.head(6)
# Out:
#                                                 Name  Price  Rating
# 0  acer Aspire 7 Core i5 12th Gen - (8 GB/512 GB ...  57490     4.3
# 1  acer Aspire 7 Core i5 12th Gen - (16 GB/512 GB...  53990     4.3
# 2  DELL Inspiron Ryzen 3 Dual Core 3250U - (8 GB/...  39690     4.3
# 3  Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  44999     4.3
# 4  ASUS Vivobook 15 Core i3 10th Gen - (8 GB/256 ...  27990     4.3
# 5  realme Book(Slim) Intel Evo Core i5 11th Gen -...  41990     4.3

# %% [markdown]
# The tail() method returns a specified number of last rows. The tail() method returns the last 5 rows if a number is not specified

# %%
df.tail()
# Out:
#                                                   Name  Price  Rating
# 931  acer Nitro 5 Ryzen 5 Hexa Core AMD R5-5600H - ...  57990     4.3
# 932  HP 14s Core i3 11th Gen - (8 GB/256 GB SSD/Win...  40400     4.3
# 933  DELL Athlon Dual Core 11th Gen - (8 GB/256 GB ...  34499     4.3
# 934  DELL Core i5 11th Gen - (8 GB/512 GB SSD/Windo...  56990     4.3
# 935  Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...  53990     4.3

# %% [markdown]
# The info() method prints information about the DataFrame. The information contains the number of columns, column labels, column data types, memory usage, range index, and the number of cells in each column (non-null values). Note: the info() method actually prints the info.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 936 entries, 0 to 935
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    936 non-null    object
#  1   Price   936 non-null    int64
#  2   Rating  936 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 29.2+ KB

# %% [markdown]
# The describe() method returns description of the data in the DataFrame. If the DataFrame contains numerical data, the description contains these information for each column: count - The number of not-empty values. mean - The average (mean) value

# %%
df.describe()
# Out:
#                Price      Rating
# count     936.000000  936.000000
# mean    75746.465812    4.384615
# std     55891.976308    0.287974
# min     13990.000000    3.800000
# 25%     44217.250000    4.300000
# 50%     57990.000000    4.300000
# 75%     79990.000000    4.600000
# max    499990.000000    5.000000

# %% [markdown]
# # Data Manipulation

# %% [markdown]
# Use the df.rename() function and refer the columns to be renamed. Not all the columns have to be renamed:

# %%
df.rename({"Name":"Title"}, axis = 1, inplace = True)
df
# Out:
#                                                  Title  Price  Rating
# 0    acer Aspire 7 Core i5 12th Gen - (8 GB/512 GB ...  57490     4.3
# 1    acer Aspire 7 Core i5 12th Gen - (16 GB/512 GB...  53990     4.3
# 2    DELL Inspiron Ryzen 3 Dual Core 3250U - (8 GB/...  39690     4.3
# 3    Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  44999     4.3
# 4    ASUS Vivobook 15 Core i3 10th Gen - (8 GB/256 ...  27990     4.3
# ..                                                 ...    ...     ...
# 931  acer Nitro 5 Ryzen 5 Hexa Core AMD R5-5600H - ...  57990     4.3
# 932  HP 14s Core i3 11th Gen - (8 GB/256 GB SSD/Win...  40400     4.3
# 933  DELL Athlon Dual Core 11th Gen - (8 GB/256 GB ...  34499     4.3
# 934  DELL Core i5 11th Gen - (8 GB/512 GB SSD/Windo...  56990     4.3
# 935  Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...  53990     4.3
#
# [936 rows x 3 columns]

# %% [markdown]
# # Accesing the column

# %%
df["Rating"] = 4.3

# %%
df
# Out:
#      Title  Price  Rating
# 0      4.3  57490     4.3
# 1      4.3  53990     4.3
# 2      4.3  39690     4.3
# 3      4.3  44999     4.3
# 4      4.3  27990     4.3
# ..     ...    ...     ...
# 931    4.3  57990     4.3
# 932    4.3  40400     4.3
# 933    4.3  34499     4.3
# 934    4.3  56990     4.3
# 935    4.3  53990     4.3
#
# [936 rows x 3 columns]

# %%
df = pd.read_csv('Flipkart_laptops.csv', index_col = 0)
df
# Out:
#                                                   Name  Price  Rating
# 0    acer Aspire 7 Core i5 12th Gen - (8 GB/512 GB ...  57490     4.3
# 1    acer Aspire 7 Core i5 12th Gen - (16 GB/512 GB...  53990     4.3
# 2    DELL Inspiron Ryzen 3 Dual Core 3250U - (8 GB/...  39690     4.3
# 3    Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  44999     4.3
# 4    ASUS Vivobook 15 Core i3 10th Gen - (8 GB/256 ...  27990     4.3
# ..                                                 ...    ...     ...
# 931  acer Nitro 5 Ryzen 5 Hexa Core AMD R5-5600H - ...  57990     4.3
# 932  HP 14s Core i3 11th Gen - (8 GB/256 GB SSD/Win...  40400     4.3
# 933  DELL Athlon Dual Core 11th Gen - (8 GB/256 GB ...  34499     4.3
# 934  DELL Core i5 11th Gen - (8 GB/512 GB SSD/Windo...  56990     4.3
# 935  Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...  53990     4.3
#
# [936 rows x 3 columns]

# %% [markdown]
# # How to extract daata from dataset

# %%
import pandas as pd
def extract_data(value):
    if value:
        value_o=value.split()[0]
        value_o=value_o.replace(",", "")
        return value_o
    else:
        return np.nan

# %% [markdown]
# # Use apply function and creating new column in dataset

# %%
df["Brand"]=df["Name"].apply(extract_data)

# %%
df
# Out:
#                                                   Name  Price  Rating   Brand
# 0    acer Aspire 7 Core i5 12th Gen - (8 GB/512 GB ...  57490     4.3    acer
# 1    acer Aspire 7 Core i5 12th Gen - (16 GB/512 GB...  53990     4.3    acer
# 2    DELL Inspiron Ryzen 3 Dual Core 3250U - (8 GB/...  39690     4.3    DELL
# 3    Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  44999     4.3  Lenovo
# 4    ASUS Vivobook 15 Core i3 10th Gen - (8 GB/256 ...  27990     4.3    ASUS
# ..                                                 ...    ...     ...     ...
# 931  acer Nitro 5 Ryzen 5 Hexa Core AMD R5-5600H - ...  57990     4.3    acer
# 932  HP 14s Core i3 11th Gen - (8 GB/256 GB SSD/Win...  40400     4.3      HP
# 933  DELL Athlon Dual Core 11th Gen - (8 GB/256 GB ...  34499     4.3    DELL
# 934  DELL Core i5 11th Gen - (8 GB/512 GB SSD/Windo...  56990     4.3    DELL
# 935  Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...  53990     4.3  Lenovo
#
# [936 rows x 4 columns]

# %% [markdown]
# # Drop Function

# %%
df.drop(columns=["Rating"], inplace = True)

# %%
df
# Out:
#                                                   Name  Price   Brand
# 0    acer Aspire 7 Core i5 12th Gen - (8 GB/512 GB ...  57490    acer
# 1    acer Aspire 7 Core i5 12th Gen - (16 GB/512 GB...  53990    acer
# 2    DELL Inspiron Ryzen 3 Dual Core 3250U - (8 GB/...  39690    DELL
# 3    Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  44999  Lenovo
# 4    ASUS Vivobook 15 Core i3 10th Gen - (8 GB/256 ...  27990    ASUS
# ..                                                 ...    ...     ...
# 931  acer Nitro 5 Ryzen 5 Hexa Core AMD R5-5600H - ...  57990    acer
# 932  HP 14s Core i3 11th Gen - (8 GB/256 GB SSD/Win...  40400      HP
# 933  DELL Athlon Dual Core 11th Gen - (8 GB/256 GB ...  34499    DELL
# 934  DELL Core i5 11th Gen - (8 GB/512 GB SSD/Windo...  56990    DELL
# 935  Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...  53990  Lenovo
#
# [936 rows x 3 columns]

# %%
link=[str(False) for i in range(0,936)]

# %%
df["Link"] = link

# %%
df
# Out:
#                                                   Name  Price   Brand   Link
# 0    acer Aspire 7 Core i5 12th Gen - (8 GB/512 GB ...  57490    acer  False
# 1    acer Aspire 7 Core i5 12th Gen - (16 GB/512 GB...  53990    acer  False
# 2    DELL Inspiron Ryzen 3 Dual Core 3250U - (8 GB/...  39690    DELL  False
# 3    Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  44999  Lenovo  False
# 4    ASUS Vivobook 15 Core i3 10th Gen - (8 GB/256 ...  27990    ASUS  False
# ..                                                 ...    ...     ...    ...
# 931  acer Nitro 5 Ryzen 5 Hexa Core AMD R5-5600H - ...  57990    acer  False
# 932  HP 14s Core i3 11th Gen - (8 GB/256 GB SSD/Win...  40400      HP  False
# 933  DELL Athlon Dual Core 11th Gen - (8 GB/256 GB ...  34499    DELL  False
# 934  DELL Core i5 11th Gen - (8 GB/512 GB SSD/Windo...  56990    DELL  False
# 935  Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...  53990  Lenovo  False
#
# [936 rows x 4 columns]

# %%
df["Link"] = df["Link"].apply(lambda x : 'https://www.flipkart.com')

# %%
df
# Out:
#                                                   Name  Price   Brand  \
# 0    acer Aspire 7 Core i5 12th Gen - (8 GB/512 GB ...  57490    acer
# 1    acer Aspire 7 Core i5 12th Gen - (16 GB/512 GB...  53990    acer
# 2    DELL Inspiron Ryzen 3 Dual Core 3250U - (8 GB/...  39690    DELL
# 3    Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  44999  Lenovo
# 4    ASUS Vivobook 15 Core i3 10th Gen - (8 GB/256 ...  27990    ASUS
# ..                                                 ...    ...     ...
# 931  acer Nitro 5 Ryzen 5 Hexa Core AMD R5-5600H - ...  57990    acer
# 932  HP 14s Core i3 11th Gen - (8 GB/256 GB SSD/Win...  40400      HP
# 933  DELL Athlon Dual Core 11th Gen - (8 GB/256 GB ...  34499    DELL
# 934  DELL Core i5 11th Gen - (8 GB/512 GB SSD/Windo...  56990    DELL
# 935  Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...  53990  Lenovo
#
#                          Link
# 0    https://www.flipkart.com
# 1    https://www.flipkart.com
# 2    https://www.flipkart.com
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 936 entries, 0 to 935
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    936 non-null    object
#  1   Price   936 non-null    int64
#  2   Brand   936 non-null    object
#  3   Link    936 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 36.6+ KB

# %%
df.describe()
# Out:
#                Price
# count     936.000000
# mean    75746.465812
# std     55891.976308
# min     13990.000000
# 25%     44217.250000
# 50%     57990.000000
# 75%     79990.000000
# max    499990.000000

# %%
df1=df["Brand"].value_counts()

# %%
df1
# Out:
# acer         252
# ASUS         240
# DELL         118
# Lenovo       109
# HP           109
# MSI           41
# APPLE         23
# Infinix       15
# realme         8
# Vaio           5
# Avita          5
# ALIENWARE      3
# SAMSUNG        3
# RedmiBook      2
# lenovo         1
# LG             1
# Nokia          1
# Name: Brand, dtype: int64

# %%
df1.plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
df["Price"].plot(kind="hist", bins = 25, color = "red", alpha=0.5, title="Price_detection")
# Out:
# <AxesSubplot:title={'center':'Price_detection'}, ylabel='Frequency'>

# %%
df.sort_values(by="Price", ascending = False, inplace = True)

# %%
df["Price"].plot(kind="bar", title = "Review", figsize=(25,5))
# Out:
# <AxesSubplot:title={'center':'Review'}>

# %% [markdown]
# # Drop Duplicate value

# %%
df.drop_duplicates(subset=["Name"], inplace = True)

# %%
df
# Out:
#                                                   Name   Price    Brand  \
# 737  MSI GT77 Titan Core i9 12th Gen - (64 GB/2 TB ...  499990      MSI
# 585  ASUS ROG Zephyrus Duo 16 Ryzen 9 Octa Core 690...  391990     ASUS
# 459  MSI Core i9 12th Gen - (32 GB/2 TB SSD/Windows...  390990      MSI
# 605  ASUS ROG Zephyrus Duo 16 (2022) with 90Whr Bat...  361990     ASUS
# 634  ASUS ROG Strix Scar 17 SE (2022) with 90Whr Ba...  359990     ASUS
# ..                                                 ...     ...      ...
# 96   Infinix INBook X1 Neo Series Celeron Quad Core...   18990  Infinix
# 232  ASUS (2022) Celeron Dual Core - (4 GB/128 GB S...   17990     ASUS
# 576  ASUS Chromebook Celeron Dual Core - (4 GB/64 G...   16990     ASUS
# 369  ASUS Chromebook Flip Celeron Dual Core - (4 GB...   15990     ASUS
# 490  Lenovo IdeaPad 3 Chromebook Celeron Dual Core ...   13990   Lenovo
#
#                          Link
# 737  https://www.flipkart.com
# 585  https://www.flipkart.com
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 674 entries, 737 to 490
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    674 non-null    object
#  1   Price   674 non-null    int64
#  2   Brand   674 non-null    object
#  3   Link    674 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 26.3+ KB

# %%
df.shape
# Out:
# (674, 4)

# %%
df.groupby("Brand")["Price"].min()
# Out:
# Brand
# ALIENWARE    198990
# APPLE         72490
# ASUS          15990
# Avita         34990
# DELL          30990
# HP            22992
# Infinix       18990
# LG            67490
# Lenovo        13990
# MSI           39990
# Nokia         47015
# RedmiBook     29990
# SAMSUNG       29990
# Vaio          49590
# acer          23780
# lenovo       100680
# realme        34999
# Name: Price, dtype: int64
